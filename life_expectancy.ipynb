# %% [markdown]
# ## Ingest

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nogibjj/data-science-projects/1eb810cd493316c52bfcf0d14122dde4727e5ac6/projects/le2020.csv")
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  65.662000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  42.716053
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.446000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.205380
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.524000
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0  66.074000  66.444000  66.787000  67.113000  67.435000  ...  75.441000
# 1  43.166935  43.603990  44.025617  44.432721  44.826919  ...  60.953363
# ...

# %%
fle = pd.read_csv("https://raw.githubusercontent.com/nogibjj/data-science-projects/1eb810cd493316c52bfcf0d14122dde4727e5ac6/projects/fle2022.csv")
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  65.662000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  42.716053
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.446000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.205380
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.524000
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0  66.074000  66.444000  66.787000  67.113000  67.435000  ...  75.441000
# 1  43.166935  43.603990  44.025617  44.432721  44.826919  ...  60.953363
# ...

# %%
fle.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
fle[["Country Name", "2020"]].sort_values(by="2020", ascending=False).head(25)
# Out:
#              Country Name       2020
# 96   Hong Kong SAR, China  88.000000
# 119                 Japan  87.740000
# 146      Macao SAR, China  87.307000
# 126           Korea, Rep.  86.500000
# 208             Singapore  86.100000
# 27                Bermuda  86.000000
# 78          Faroe Islands  85.500000
# 77                 France  85.300000
# 13              Australia  85.300000
# 37            Switzerland  85.200000
# 70                  Spain  85.100000
# 38        Channel Islands  85.031000
# 75                Finland  85.000000
# 177                Norway  84.900000
# 115                Israel  84.800000
# 116                 Italy  84.700000
# 159                 Malta  84.600000
# 114               Iceland  84.500000
# 144            Luxembourg  84.200000
# 223                Sweden  84.200000
# 68              Euro area  84.188239
# 194              Portugal  84.100000
# 111               Ireland  84.100000
# 180           New Zealand  83.900000
# ...

# %%
fle[["Country Name", "2020"]].sort_values(by="2020", ascending=False).head(25).to_csv("top25_female_life_expt_2020.csv")

# %%
df.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  237.000000  238.000000  238.000000  237.000000  237.000000  238.000000
# mean    53.284177   53.835229   54.226164   54.600089   55.086419   55.568213
# std     11.847831   11.846881   11.699099   11.584891   11.542193   11.420279
# min     28.199000   28.345000   28.535000   28.782000   29.097000   29.489000
# 25%     43.250962   43.919437   44.380485   45.110000   45.727000   46.205531
# 50%     51.971000   53.155052   53.759500   54.403000   54.849000   55.507954
# 75%     63.881000   64.775250   65.064976   65.348000   65.463000   66.277500
# max     73.549756   73.652683   73.721951   73.555366   73.733171   73.868780
#
#              1966        1967        1968        1969  ...        2013  \
# count  238.000000  238.000000  238.000000  238.000000  ...  248.000000
# mean    56.029432   56.450170   56.842854   57.223302  ...   71.131373
# ...

# %%
df.isna()
# Out:
#      Country Name  Country Code  Indicator Name  Indicator Code   1960   1961  \
# 0           False         False           False           False  False  False
# 1           False         False           False           False  False  False
# 2           False         False           False           False  False  False
# 3           False         False           False           False  False  False
# 4           False         False           False           False  False  False
# ..            ...           ...             ...             ...    ...    ...
# 261         False         False           False           False   True   True
# 262         False         False           False           False  False  False
# 263         False         False           False           False  False  False
# 264         False         False           False           False  False  False
# 265         False         False           False           False  False  False
#
# ...

# %%
#sort all the data by country life expectancy being highest to lowest
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
df[["Country Name", "2020"]].sort_values(by="2020", ascending=False)
# Out:
#                   Country Name       2020
# 96        Hong Kong SAR, China  85.387805
# 119                      Japan  84.615610
# 146           Macao SAR, China  84.370000
# 208                  Singapore  83.743902
# 126                Korea, Rep.  83.426829
# ..                         ...        ...
# 212                 San Marino        NaN
# 225  Sint Maarten (Dutch part)        NaN
# 228   Turks and Caicos Islands        NaN
# 245                     Tuvalu        NaN
# 255     British Virgin Islands        NaN
#
# [266 rows x 2 columns]

# %%
df2020 = df[["Country Name", "2020"]].sort_values(by="2020", ascending=False)

# %%
#data source is openai chatGPT
female_data = {'Country': ['Japan', 'Spain', 'Switzerland', 'Singapore', 'France', 'Italy', 'Australia', 'South Korea', 'Canada', 'Israel'],
'Life Expectancy for Women': [85, 85, 85, 85, 85, 84, 84, 84, 84, 84]
}

df_female_le = pd.DataFrame(female_data)
print(df_female_le)
# Out:
#        Country  Life Expectancy for Women
# 0        Japan                         85
# 1        Spain                         85
# 2  Switzerland                         85
# 3    Singapore                         85
# 4       France                         85
# 5        Italy                         84
# 6    Australia                         84
# 7  South Korea                         84
# 8       Canada                         84
# 9       Israel                         84

# %% [markdown]
# ## EDA

# %%
df2020.describe()
# Out:
#              2020
# count  247.000000
# mean    72.669217
# std      7.081598
# min     53.679000
# 25%     67.781500
# 50%     73.870906
# 75%     77.634695
# max     85.387805

# %%
#find countries simliar to the US in terms of life expectancy
df2020[df2020["Country Name"].str.contains("United States")]
# Out:
#       Country Name       2020
# 251  United States  77.280488

# %%
#get a list of g20 countries from the internet
g20 = ["Argentina", "Australia", "Brazil", "Canada", "China", "France", "Germany", "India", "Indonesia", "Italy", "Japan", "Mexico", "Russia", "Saudi Arabia", "South Africa", "South Korea", "Turkey", "United Kingdom", "United States", "European Union"]
#subset the data to only include g20 countries
df2020[df2020["Country Name"].isin(g20)]
# Out:
#        Country Name       2020
# 119           Japan  84.615610
# 13        Australia  83.200000
# 116           Italy  82.343902
# 77           France  82.175610
# 35           Canada  81.748780
# 55          Germany  80.941463
# 81   United Kingdom  80.902439
# 73   European Union  80.463702
# 251   United States  77.280488
# 40            China  77.097000
# 9         Argentina  76.813000
# 29           Brazil  76.084000
# 205    Saudi Arabia  75.280000
# 154          Mexico  75.131000
# 106       Indonesia  71.908000
# 109           India  69.887000
# 263    South Africa  64.379000

# %%
df2020[df2020["Country Name"].isin(g20)].describe()
# Out:
#             2020
# count  17.000000
# mean   77.661823
# std     5.320212
# min    64.379000
# 25%    75.280000
# 50%    77.280488
# 75%    81.748780
# max    84.615610

# %%
#show five countries with similar life expectancy in 2020 as the median life expectancy
df2020.sort_values(by="2020", ascending=False).head(55)
# Out:
#                   Country Name       2020
# 96        Hong Kong SAR, China  85.387805
# 119                      Japan  84.615610
# 146           Macao SAR, China  84.370000
# 208                  Singapore  83.743902
# 126                Korea, Rep.  83.426829
# 38             Channel Islands  83.240000
# 177                     Norway  83.209756
# 13                   Australia  83.200000
# 37                 Switzerland  83.100000
# 78               Faroe Islands  83.092683
# 114                    Iceland  83.065854
# 115                     Israel  82.700000
# 159                      Malta  82.653659
# 223                     Sweden  82.407317
# 116                      Italy  82.343902
# 70                       Spain  82.334146
# 111                    Ireland  82.204878
# 77                      France  82.175610
# 75                     Finland  82.131707
# 180                New Zealand  82.056098
# 27                     Bermuda  82.056098
# ...

# %%
top_20 = pd.read_csv("top25_female_life_expt_2020.csv")
top_20
# Out:
#     Unnamed: 0          Country Name       2020
# 0           96  Hong Kong SAR, China  88.000000
# 1          119                 Japan  87.740000
# 2          146      Macao SAR, China  87.307000
# 3          126           Korea, Rep.  86.500000
# 4          208             Singapore  86.100000
# 5           27               Bermuda  86.000000
# 6           78         Faroe Islands  85.500000
# 7           77                France  85.300000
# 8           13             Australia  85.300000
# 9           37           Switzerland  85.200000
# 10          70                 Spain  85.100000
# 11          38       Channel Islands  85.031000
# 12          75               Finland  85.000000
# 13         177                Norway  84.900000
# 14         115                Israel  84.800000
# 15         116                 Italy  84.700000
# 16         159                 Malta  84.600000
# 17         114               Iceland  84.500000
# 18         144            Luxembourg  84.200000
# ...

# %% [markdown]
# ### Visualize

# %%
import seaborn as sns

# %%
sns.relplot(data=top_20, x="2020",y="Country Name")
